# %% [markdown]
# ![Screenshot 2025-03-09 120932.png](data:image/png;base64,...)

# %%
class Solution:
    def twoSum(self, nums, target):
        numMap = {}
        for i, num in enumerate(nums):
            complement = target - num
            if complement in numMap:
                return [numMap[complement], i]
            numMap[num] = i

a = Solution()
a.twoSum([2,7,11,15],9)
# Out:
# [0, 1]
