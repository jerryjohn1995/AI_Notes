# %% [markdown]
# ![Screenshot 2025-03-08 195505.png](data:image/png;base64,...)

# %%
class Solution:
    def sum(self, num1: int, num2: int) -> int:
        return num1 + num2

a = Solution()
a.sum(2,2)
# Out:
# 4
