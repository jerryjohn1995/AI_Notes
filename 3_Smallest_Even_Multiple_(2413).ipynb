# %% [markdown]
# ![Screenshot 2025-03-08 193452.png](data:image/png;base64,...)

# %% [markdown]
# ```Python
# class Solution:
#     def smallestEvenMultiple(self, n: int) -> int:
#         # Check if n is even by using the modulo operator.
#         # If n is even, it is already the smallest even multiple, so we return it.
#         if n % 2 == 0:
#             return n
#         else:
#             # If n is odd, the smallest even multiple is n multiplied by 2.
#             return n * 2
# ```

# %%
class Solution:
    def smallestEvenMultiple(self, n: int) -> int:
        # Check if n is even by using the modulo operator.
        # If n is even, it is already the smallest even multiple, so we return it.
        if n % 2 == 0:
            return n
        else:
            # If n is odd, the smallest even multiple is n multiplied by 2.
            return n * 2

a = Solution()
a.smallestEvenMultiple(5)
# Out:
# 10
